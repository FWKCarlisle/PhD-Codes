# %%
import matplotlib.pyplot as plt
import numpy as np




saturation_BP = [1.239343,1.1280,1.1478,1.0631,1.12768,1.06549,1.145,0.8519,1.0798,0.8947,0.78448,0.935659,1.009995,1.06756,1.08693,0.839947,0.87358,0.96287,0.9250925,1.2214]
rem_BP = [0.57908,0.18008,0.153397, 0.0882,0.12549899,0.07769,0.0588919,0.02605,0.07149,0.0361657,0.0307675,0.03200,0.054966,0.088232, 0.097713,0.039417,0.031837,0.03597868,0.030614,0.0709705,0.048648408734500645]
temp_BP = [2,8,10,11.8,11,12.2,12.4,12.5,12.6,12.6,12.6,12.7,12.8,12.9,12,13,14,15,17,13,12.8]
good_bad = [0.5]

Tc = 13
temp = np.arange(0,13,0.01)
temp_tc = 0.15*(1-temp/Tc)**0.225

# plt.plot(temp, temp_tc)

plt.scatter(temp_BP, rem_BP)

plt.xlim(11,14)
plt.ylim(-0.01, 0.2)
# Out:
# (-0.01, 0.2)
