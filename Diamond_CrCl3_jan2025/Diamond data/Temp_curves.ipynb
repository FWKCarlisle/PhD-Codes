# %%
import matplotlib.pyplot as plt
import numpy as np




rem_BP = [0.1515,0.086948,0.1233,0.0758, 0.05889,0.0449,0.071269,0.04814,0.0400,0.05168,0.05433,0.04864,0.08717,0.0955,0.08271,0.0704,0.0429,0.07097,0.0381,0.049,0.0409,0.5701,0.1774]
temp_BP = [10,11.8,11,12.2,12.4,12.5,12.6,12.6,12.6,12.7,12.8,12.8,12.9,12,12,13.2,13,13,14,15,17,2,8]
good_bad = [1, 1, 1, 1, 1,0,1,0.25,0,0.5,0.75,0.75,0.75,1,1,1,0,1,0.25,0.5,1,1,1]

Tc = 13
temp = np.arange(0,13,0.01)
temp_tc = 0.15*(1-temp/Tc)**0.225

# plt.plot(temp, temp_tc)
print(len(rem_BP), len(temp_BP), len(saturation_BP))
plt.scatter(temp_BP, rem_BP, c=good_bad)
# plt.scatter(temp_BP, saturation_BP, c=rem_BP)
plt.colorbar()

plt.xlim(9.5,15)
plt.ylim(-0.01, 0.2)
# Out:
# 23 23 21
# (-0.01, 0.2)
