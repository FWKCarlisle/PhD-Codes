# %% [markdown]
# # I06-1 beamtime MM33878-1
# *Experiment Logbook for I06*
#
# Date: Wednesday, 13th February 2024
#
# Data directory: `/dls/i06-1/data/2024/mm33878-1`
#
# Users present:
#
# Samples:
#
# Beamline setup:
# Branchline, Magnet, cooling

# %%
# !pip install lmfit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %autosave 60
# %matplotlib notebook
import sys, os
import numpy as npXAS
import matplotlib.pyplot as plt
from matplotlib import dates
from datetime import datetime
from scipy import integrate
from scipy.signal import convolve
from lmfit import minimize, Parameters, Parameter, report_fit 
from lmfit.models import  ConstantModel, VoigtModel, Pearson7Model,GaussianModel, LorentzianModel, LinearModel, ExpressionModel,PolynomialModel,ExponentialModel,StepModel,RectangleModel,LinearModel, QuadraticModel, DampedOscillatorModel
from scipy.interpolate import interp1d

sys.path.append('/dls_sw/i06-1/scripts/python_scripts/Magnet')

import Py06functions_Nexus as bl 

print("ALL GOOD BOSS")
# Out:
# Autosaving every 60 seconds
# ALL GOOD BOSS

# %%
bl.filedir = '/dls/i06-1/data/2024/mm34878-1/'
bl.savedir = '/dls/i06-1/data/2024/mm34878-1/processing/output/'

# %% [markdown]
# # Sample 1:

# %%
#XMCD/XMLD
#Fe

#XMCD_T_CFB_9_1T=bl.calc_XMCD_Nexus(range(313620,313622),'T-CFB-9','TEY','norm',False,None,False)
#XMCD_T_CFB_9_0T=bl.calc_XMCD_Nexus(range(313628,313630),'T-CFB-9','TEY','norm',False,None,False)
#Co
#XMCD_T_CFB_9_Co_1T=bl.calc_XMCD_Nexus(range(328,313624),'T-CFB-9','TEY','norm',False,None,False)
#XMCD_T_CFB_9_Co_0T=bl.calc_XMCD_Nexus(range(313630,313632),'T-CFB-9','TEY','norm',False,None,False)
#Mn FM
#XMCD_T_CFB_9_Mn_1T=bl.calc_XMCD_Nexus(range(328464,328468),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328401,328403),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328403,328405),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328405,328407),'T-CFB-9','TEY','norm',False,None,False)

# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328407,328409),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328409,328411),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328411,328413),'T-CFB-9','TEY','norm',False,None,False)

# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328413,328415),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328415,328417),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328417,328419),'T-CFB-9','TEY','norm',False,None,False)

# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328419,328421),'T-CFB-9','TEY','norm',False,None,False)
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(328421,328423),'T-CFB-9','TEY','norm',False,None,False)

#XMCD varying field
XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(330645,330650
                                           ),'T-CFB-9','TEY','norm',False,'peak',False) 
XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(330730,330735),'T-CFB-9','TEY','norm',False,'peak',False) 
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(329873,329877),'T-CFB-9','TFY_90','norm',False,'peak',False) 
# XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(329877,329882),'T-CFB-9','TFY_90','norm',False,'peak',False) 
#XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus((329845,329846,329847,329848,329849),'T-CFB-9','TFY_90','norm',False,None,False) 
#XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(329920,329926),'T-CFB-9','TEY','norm',False,'peak',False) 
#XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(330206,330211),'T-CFB-9','TFY_90','norm',False,'peak',False) 
help(bl.calc_XMCD_Nexus)
#Mn AF
#XMLD_T_CFB_9_MnAF_1T=bl.calc_XMLD_Nexus(range(313626,313628),'T-CFB-9','TEY','norm',False,None,False)
#XMLD_T_CFB_9_MnAF_0T=bl.calc_XMLD_Nexus(range(313634,313636),'T-CFB-9','TEY','norm',False,None,False)

#XMCD_Sample1_2K=bl.calc_XMCD_pairs_Nexus(range(100000,100002),'Sample name','TEY','norm',False,None,False)
#XMLD_Sample1_2K=bl.calc_XMLD_Nexus(range(313626,313628),'Sample name','TEY','norm',False,None,False)
# Out:
# Scan 330645 doesn't exist or can't be read
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 27
#       1 #XMCD/XMLD
#       2 #Fe
#       3
#    (...)
#      25
#      26 #XMCD varying field
# ---> 27 XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(330645,330650
#      28                                            ),'T-CFB-9','TEY','norm',False,'peak',False)
#      29 XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(330730,330735),'T-CFB-9','TEY','norm',False,'peak',False)
#      30 # XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(329873,329877),'T-CFB-9','TFY_90','norm',False,'peak',False)
#      31 # XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus(range(329877,329882),'T-CFB-9','TFY_90','norm',False,'peak',False)
#      32 #XMCD_T_CFB_9_Mn_0T=bl.calc_XMCD_Nexus((329845,329846,329847,329848,329849),'T-CFB-9','TFY_90','norm',False,None,False)
# ...

# %%
#Summary plot
plt.figure()
plt.subplot(2, 2, 1)
plt.suptitle(r'Sample name, XMCD, TEY, $\phi=0^{\circ}$',fontsize=14)
plt.plot(XMCD_T_CFB_9_1T[0],XMCD_T_CFB_9_1T[1],label='1T')
plt.plot(XMCD_T_CFB_9_0T[0],XMCD_T_CFB_9_0T[1],label='0T')
plt.subplot(2, 2, 2)
plt.plot(XMCD_T_CFB_9_Co_1T[0],XMCD_T_CFB_9_Co_1T[1],label='1T')
plt.plot(XMCD_T_CFB_9_Co_0T[0],XMCD_T_CFB_9_Co_0T[1],label='0T')
plt.subplot(2, 2, 3)
plt.plot(XMCD_T_CFB_9_Mn_1T[0],XMCD_T_CFB_9_Mn_1T[1],label='1T')
plt.plot(XXASMCD_T_CFB_9_Mn_0T[0],XMCD_T_CFB_9_Mn_0T[1],label='0T')
plt.subplot(2, 2, 4)
plt.plot(XMLD_T_CFB_9_MnAF_1T[0],XMLD_T_CFB_9_MnAF_1T[1],label='1T')
plt.plot(XMLD_T_CFB_9_MnAF_0T[0],XMLD_T_CFB_9_MnAF_0T[1],label='0T')

plt.axhline(y=0,ls='--',color='black')
plt.legend(loc=0,frameon=False,fontsize=8)
plt.xlabel('Energy (eV)', fontsize=14)
plt.ylabel('XMCD (arb. units)',fontsize=14)
plt.tick_params(direction='in',labelsize=14)
#plt.xlim([565,600])
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
#Hysteresis
Co_hyst=bl.hysteresis_Nexus(range(328549,328553)XAS,'Sample name',None,False)
Co_hyst=bl.hysteresis_Nexus(range(328560,328564),'Sample name',None,False)
Co_hyst=bl.hysteresis_Nexus(range(328567,328571),'Sample name',None,False)
Co_hyst=bl.hysteresis_Nexus(range(328587,328591),'Sample name',None,False)
#Tb_hyst=bl.hysteresis1branch_Nexus(range(309301,309303),'M5_122',None,False)
#Information
#bl.read_Nexus_file([100000])
# Out:
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %%
def normalise_XMCD(sets):
    return

def hysterisis_from_specrta(spectra_XMCD_sets,field_values):
    XMCD_set_1 = bl.calc_XMCD_Nexus(range(spectra_XMCD_sets[0,0],spectra_XMCD_sets[0,1]),'T-CFB-9','TEY','norm',False,None,False)
    XMCD_sets = np.zeros((len(spectra_XMCD_sets),len(XMCD_set_1)))
    for i in range(len(spectra_XMCD_sets)):
        XMCD_sets[i] = bl.calc_XMCD_Nexus(range(spectra_XMCD_sets[0,0],spectra_XMCD_sets[0,1]),'T-CFB-9','TEY','norm',False,None,False)
    #normalise XMCD
    normalise_XMCD(XMCD_sets)
    return

# %%
def hysteresis_Nexus(scanlist,sample_name,exclude_list=None,save=False):
    
    """Plot hysteresis in TEY and TFY mode;
    
    Parameters
    ------------
    scanlist: list with scan numbers (pc and nc scans)
    
    sample_name: add the name of the sample as string; e.g. 'Sample 1'
    
    exclude_list: list of magnetic fields to be excluded from the analysis
   
    save: if True, saves the plots and the .dat file with the results 
    
    Returns
    --------
    Plot of hysteresis for each polarisation and ramp up and down
    """
    
    TEY_pc_up = []
    TEY_pc_down = []
    TEY_nc_up = []
    TEY_nc_down = []
    
    TFY_pc_up = []
    TFY_pc_down = []
    TFY_nc_up = []
    TFY_nc_down = []
    
    "Getting information from the first scan"
    
    d=readscan_Nexus(scanlist[0])
    
    if d.metadata.endstation == ['XABS','DD']:
        print('Error!!! This function just works for the magnet endstation')
        return
       
    else:
        if 'Tsample_mag' in d.metadata:
            tmp = str(d.metadata.Tsample_mag)
        else:
            tmp = 'n/a'
    
        if 'scmth' in d.metadata:
            rot = str(int(d.metadata.scmth))
        else:
            rot = 'n/a'
    
    ttl1 = r'#%d-#%d, %s, T=%s K, $\theta=%s^{\circ}$'%(scanlist[0],scanlist[-1],sample_name,tmp,rot)
    
    
    
    
    plt.figure(figsize=[9,6])
    plt.suptitle(ttl1,fontsize=14)
    ax0 = plt.subplot(2,2,1)
    ax1 = plt.subplot(2,2,2)
    ax2 = plt.subplot(2,2,3)
    ax3 = plt.subplot(2,2,4)
    
    
    for scanno in scanlist:
        field_filtered = []
        index_list =[]
        TFY_filtered = []
        TFY_exclude =[]
        TEY_filtered = []
        TEY_exclude =[]
        
        d=readscan_Nexus(scanno)
        field = d.hyst2
     
        TEY = d.ridio
        TFY = d.rifio
        
        
        "Removing the region defined in exclude_list"
        
        if exclude_list is not None:
            if type(exclude_list) != list:
                exclude_list = exclude_list.tolist()
                exclude_list = [round(num, 1) for num in exclude_list]
                #print(exclude_list)
            
            else:
                exclude_list=exclude_list
                
            for index,val in enumerate(field):
                if val not in exclude_list:
                    field_filtered.append(val)
                        
                else:
                    index_list.append(index)
                
            "Removing the region close to mgaz=0 in the TEY and TFY arrays "
            
            for item,val in enumerate(TEY):
                if item not in index_list:
                    TEY_filtered.append(val)
                else:
                    TEY_exclude.append(val)
            
            for item,val in enumerate(TFY):
                if item not in index_list:
                    TFY_filtered.append(val)
                else:
                    TFY_exclude.append(val)
   
        else:
            field_filtered = field
            TEY_filtered = TEY
            TFY_filtered = TFY
        
        if d.metadata.iddgap == 100:
            rowphase = d.metadata.idutrp
        else:
            rowphase = d.metadata.iddtrp
        
        pol = d.metadata.pola
        
        if pol == 'pc':
            if field_filtered[-1]>field_filtered[1]:
                ax0.plot(field_filtered,TEY_filtered,color='C0',label='pc, up')
                ax1.plot(field_filtered,TFY_filtered,color='C0',label='pc, up')
                TEY_pc_up.append(TEY_filtered)
                TFY_pc_up.append(TFY_filtered)
            else:
                ax0.plot(field_filtered,TEY_filtered,'--',color='C0',label='pc,down')
                ax1.plot(field_filtered,TFY_filtered,'--',color='C0',label='pc,down')
                TEY_filtered = np.flipud(TEY_filtered)
                TFY_filtered = np.flipud(TFY_filtered)
                
                TEY_pc_down.append(TEY_filtered)
                TFY_pc_down.append(TFY_filtered)
  
        
        if pol == 'nc':
            if field_filtered[-1]>field_filtered[1]:
                ax0.plot(field_filtered,TEY_filtered,color='C1',label='nc, up')
                ax1.plot(field_filtered,TFY_filtered,color='C1',label='nc, up')
                TEY_nc_up.append(TEY_filtered)
                TFY_nc_up.append(TFY_filtered)_ipython().system('pip install nexusfor
            else:
                ax0.plot(field_filtered,TEY_filtered,'--',color='C1',label='nc,down')
                ax1.plot(field_filtered,TFY_filtered,'--',color='C1',label='nc,down')
                TEY_filtered = np.flipud(TEY_filtered)
                TFY_filtered = np.flipud(TFY_filtered)
                
                TEY_nc_down.append(TEY_filtered)
                TFY_nc_down.append(TFY_filtered)
                
                
    ax0.legend(loc=0,frameon=False,fontsize=10)
    ax0.set_ylabel('TEY (arb. units)',fontsize=12)
    ax0.tick_params(direction='in',labelbottom=False,labelsize=12)
    ax1.legend(loc=0,frameon=False,fontsize=10)
    ax1.set_ylabel('TFY (arb. units)',fontsize=12)
    ax1.tick_params(direction='in',labelbottom=False,labelsize=12)
    
    TEY_pc_up = np.array(TEY_pc_up)
    TEY_pc_down = np.array(TEY_pc_down)
    TEY_nc_up = np.array(TEY_nc_up)
    TEY_nc_down = np.array(TEY_nc_down)
    
    TFY_pc_up = np.array(TFY_pc_up)
    TFY_pc_down = np.array(TFY_pc_down)
    TFY_nc_up = np.array(TFY_nc_up)
    TFY_nc_down = np.array(TFY_nc_down)
    
    TEY_xmcd_up = TEY_pc_up-TEY_nc_up
    TEY_xmcd_down = TEY_pc_down-TEY_nc_down
    
    TFY_xmcd_up = TFY_pc_up-TFY_nc_up
    TFY_xmcd_down = TFY_pc_down-TFY_nc_down
    
    "getting field values based on the first scan of a sequence"
  
    if field_filtered[-1]>field_filtered[1]:
        field_final = field_filtered
        
    else:
        field_final = np.flipud(field_filtered)
    
    for i in range(len(TEY_pc_up)):
        ax2.plot(field_final,TEY_xmcd_up[i],label='xmcd__ipython().system('pip install nexusforup')
        ax2.plot(field_final,TEY_xmcd_down[i],label='xmcd_down')
    ax2.legend(loc=0,frameon=False,fontsize=12)
    ax2.set_ylabel('TEY XMCD (arb. units)',fontsize=12)
    ax2.set_xlabel('Magnetic Field (T)',fontsize=12)
    ax2.tick_params(direction='in',labelsize=12)
        
    for i in range(len(TFY_pc_up)):
        ax3.plot(field_final,TFY_xmcd_up[i],label='xmcd_up')
        ax3.plot(field_final,TFY_xmcd_down[i],label='xmcd_down')
    ax3.legend(loc=0,frameon=False,fontsize=12)
    ax3.set_ylabel('TFY XMCD (arb. units)',fontsize=12)
    ax3.set_xlabel('Magnetic Field (T)',fontsize=12)
    ax3.tick_params(direction='in',labelsize=12)
    
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    
    fig, axs = plt.subplots(1, 2,figsize=(9,5))
    for i in range(len(TEY_pc_up)):
        axs[0].plot(field_final,TEY_xmcd_up[i],'-o',color='C2',label='xmcd_up')
        axs[0].plot(field_final,TEY_xmcd_down[i],'--o',color='C2',label='xmcd_down')
    axs[0].legend(loc=0,frameon=False,fontsize=12)
    axs[0].set_ylabel('TEY XMCD (arb. units)',fontsize=14)
    axs[0].set_xlabel('Magnetic Field (T)',fontsize=14)
    axs[0].tick_params(direction='in',labelsize=14)
       
    
    for i in range(len(TFY_pc_up)):
        axs[1].plot(field_final,TFY_xmcd_up[i],'-o',color='C3',label='xmcd_up')
        axs[1].plot(field_final,TFY_xmcd_down[i],'--o',color='C3',label='xmcd_down')
    axs[1].legend(loc=0,frameon=False,fontsize=12)
    axs[1].set_xlabel('Magnetic Field (T)',fontsize=14)
    axs[1].tick_params(direction='in',labelleft=False,labelright=True,right=True,labelsize=14)
    axs[1].set_ylabel('TFY XMCD (arb. units)',fontsize=14)
    axs[1].yaxis.set_label_position("right")
    plt.suptitle(ttl1,fontsize=14)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    if save:
        plt.savefig(savedir+'figures/'+'%d-%d_%s_hyst.png'%(scanlist[0],scanlist[-1],sample_name))
        
        
        for i in range(len(TEY_pc_up)):
            txt = savedir+'data/'+'TEY_%d-%d_%s_hyst_%d.dat'%(scanlist[0],scanlist[-1],sample_name,i)
            f=open(txt, 'w')
            f.write('B[T]  pc_up  pc_down nc_up  nc_down   xmcd_up    xmcd_down\n')
            for m in range(len(field_final)): 
                help='{:5.2f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}\n'
                f.write(help.format(field_final[m], TEY_pc_up[i][m], TEY_pc_down[i][m],TEY_nc_up[i][m], TEY_nc_down[i][m], TEY_xmcd_up[i][m], TEY_xmcd_down[i][m]))
            f.close()
            
        for i in range(len(TFY_pc_up)):
            txt = savedir+'data/'+'TFY_%d-%d_%s_hyst_%d.dat'%(scanlist[0],scanlist[-1],sample_name,i)
            f=open(txt, 'w')
            f.write('B[T]  pc_up  pc_down nc_up  nc_down   xmcd_up    xmcd_down\n')
            for m in range(len(field_final)): 
                help='{:5.2f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}{:10.6f}\n'
                f.write(help.format(field_final[m], TFY_pc_up[i][m], TFY_pc_down[i][m],TFY_nc_up[i][m], TFY_nc_down[i][m], TFY_xmcd_up[i][m], TFY_xmcd_down[i][m]))
            f.close()
            
    return field_final, TEY_xmcd_up, TEY_xmcd_down, TFY_xmcd_up, TFY_xmcd_down

# %%
Co_hyst=bl.hysteresis_Nexus(range(328581,328583),'Sa347228=>347229mple name',None,False)
# Out:
# <img src="data:image/png;base64,..." width="1500">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_164927/3923682802.py in <module>
# ----> 1 Co_hyst=bl.hysteresis_Nexus(range(328581,328583),'Sample name',None,False)
#
# /dls_sw/i06-1/scripts/python_scripts/Magnet/Py06functions_Nexus.py in hysteresis_Nexus(scanlist, sample_name, exclude_list, save)
#    3328
#    3329         d=readscan_Nexus(scanno)
# -> 3330         field = d.hyst2
#    3331
#    3332         TEY = d.ridio
#
# AttributeError: 'dict2obj' object has no attribute 'hyst2'
