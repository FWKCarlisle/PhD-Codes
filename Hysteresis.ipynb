# %%
# %autosave 60
import matplotlib.pyplot as plt
import numpy as np
from nexusformat.nexus import nxload


def hysteresis (filename):
    a=nxload(filename)
    #E=a.entry.instrument.fastEnergy.value 
    #idi0=a.entry.instrument.fesData.idio
    
    B1=a.entry.instrument.hyst2.nxvalue 

    D2A=a.entry.instrument.hyst2.detector2_A.nxvalue 
    D2B=a.entry.instrument.hyst2.detector2_B.nxvalue 
    D3A=a.entry.instrument.hyst2.detector3_A.nxvalue 
    D3B=a.entry.instrument.hyst2.detector3_B.nxvalue
    
    #plt.figure(1);plt.plot(B1,D1A,'b.-') 
    #plt.figure(1);plt.plot(B1,D1B,'r.-') 
    #plt.figure(2);plt.plot(B1,D2A,'b.-') 
    #plt.figure(2);plt.plot(B1,D2B,'r.-') 
    #plt.figure(3);plt.plot(B1,D3A,'b.-') 
    #plt.figure(3);plt.plot(B1,D3B,'r.-')
    #plt.figure(1);plt.plot(B1,(D3B/D2B)/(D3A/D2A),'b.-') 
    plt.figure(1);plt.plot(B1,((D3B/D2B)-(D3A/D2A))/((D3B/D2B)+(D3A/D2A)),'b.-') 
    asym1=((D3B/D2B)-(D3A/D2A))/((D3B/D2B)+(D3A/D2A)) 
    minasym1=np.min(asym1)
    maxasym1=np.max(asy
m1) 
    normasym1=2*(asym1-(maxasym1+minasym1)/2)/(maxasym1-minasym1) 
    plt.figure(2);plt.plot(B1,normasym1,'b.-')
    plt.plot(B1, D2B)
# Out:
#   Cell In[151], line 13
#     2025-01-29 19:26:29,598 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
#          ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
files = [347106, 347107, 347108, 347109]
filepaths = []

for file in files:2025-01-29 19:28:15,620 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
2025-01-29 19:28:15,620 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
2025-01-29 19:28:15,620 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)

    filepaths.append(f"i06-1-{file}.nxs")
2025-01-29 19:26:29,598 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
2025-01-29 19:26:29,598 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
2025-01-29 19:26:29,598 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)

for file in filepaths:
    hysteresis(file)
    plt.title(file)
    plt.show()
# Out:
#   Cell In[152], line 4
#     for file in files:2025-01-29 19:28:15,620 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
#                            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
file_6 = filepaths[0] #6
file_7 = filepaths[1] #7
file_8 = filepaths[2] #8
file_9 = filepaths[3] #9

def get_values(file):
    
    nexus = nxload(file)
    TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue 
    TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue 
    I_0_A = nexus.entry.instrument.hyst2.detector2_A.nxvalue 
    I_0_B = nexus.entry.instrument.hyst2.detector2_B.nxvalue 
    
    return TEY_A, TEY_B, I_0_A, I_0_B
nexus = nxload(file_6)

B1=nexus.entry.instrument.hyst2.value.nxvalue 
TEY_A_6, TEY_B_6, I_A_6,I_B_6 = get_values(file_6) 
TEY_A_7, TEY_B_7,I_A_7,I_B_7 = get_values(file_7) 
TEY_A_8, TEY_B_8,I_A_8,I_B_8 = get_values(file_8) 
TEY_A_9, TEY_B_9,I_A_9,I_B_9 = get_values(file_9)

print(((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)))
print((TEY_A_6)-(TEY_B_6))
print(TEY_A_6,TEY_B_6)
print(I_A_6, I_B_6)
print(TEY_A_6/I_A_6, TEY_B_6/I_B_6)

plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),"s", label="6-8 Norm")
plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),label="6-8 Norm")
plt.plot(B1, - ((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),label="9-7 norm")
plt.plot(B1, - ((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),"d",label="9-7 norm")
# plt.plot(B1, (TEY_A_6)-(TEY_B_6) - ((TEY_A_8)-(TEY_B_8)), label="6-8")
# plt.plot(B1, - ((TEY_A_7)-(TEY_B_7)) + ((TEY_A_9)-(TEY_B_9)),label="9-7")
plt.axhline(y=0)
plt.axvline(x=0)
plt.legend()
# Out:
# [2.020891 1.934191 1.829508 ... 0.525969 0.482914 0.436098]
# [272587. 260800. 246347. ...  72771.  64748.  58161.]
# [479280. 468469. 452428. ... 262088. 259805. 252500.] [206693. 207669. 206081. ... 189317. 195057. 194339.]
# [135528. 135485. 135346. ... 134225. 136274. 136170.] [136386. 136308. 136185. ... 132702. 137019. 137032.]
# [3.536391 3.457719 3.342751 ... 1.952602 1.90649  1.8543  ] [1.5155   1.523528 1.513243 ... 1.426633 1.423576 1.418202]

# %%
plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8)))))/(0.25*(I_A_6 + I_B_6 + I_A_8 + I_B_8)))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))/(0.25*(I_A_7 + I_B_7 + I_A_9 + I_B_9)))

x = ((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))

print(len(x))
print(x[8])
# Out:
# 17
# -0.5196191782792213

# %%
TEY_A_6 = TEY_A_6/I_A_6
TEY_B_6 = TEY_B_6/I_B_6
TEY_A_7 = TEY_A_7/I_A_7
TEY_B_7 = TEY_B_7/I_B_7
TEY_A_8 = TEY_A_8/I_A_8
TEY_B_8 = TEY_B_8/I_B_8
TEY_A_9 = TEY_A_9/I_A_9
TEY_B_9 = TEY_B_9/I_B_9


plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7))))))
plt.axhline(y=0)
plt.axvline(x=0)

# %%
D2A=nexus.entry.instrument.hyst2.detector2_A.nxvalue 
D2B=nexus.entry.instrument.hyst2.detector2_B.nxvalue 

plt.plot(B1, D2A, label="A")#2025-01-29 22:29:21,481 WARN  gda.factory.Finder - Finder could not find an object called 'scm_amp_1'. At some point, this method will throw an exception instead of returning null!

plt.plot(B1, D2B)
plt.legend()

# %%
# Out:
#   Cell In[157], line 6
#     for file in files:2025-01-30 07:03:15,620 INFO  EnergyConsolidationClass:iddrpenergy - isBusy() = True (iddrpenergy0=True iddpol=False Timer=False)
#                            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# Second hysterisis loop 0.4T , GI ,60 dwg

filepaths = ['i06-1-347260.nxs', 'i06-1-347261.nxs', 'i06-1-347262.nxs', 'i06-1-347263.nxs']
file_6 = filepaths[0] #6
file_7 = filepaths[1] #7
file_8 = filepaths[2] #8
file_9 = filepaths[3] #9
print(filepaths)
def get_values(file):
    
    nexus = nxload(file)
    TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue 
    TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue 
    I_0_A = nexus.entry.instrument.hyst2.detector2_A.nxvalue 
    I_0_B = nexus.entry.instrument.hyst2.detector2_B.nxvalue 
    
    return TEY_A, TEY_B, I_0_A, I_0_B
nexus = nxload(file_6)

B1=nexus.entry.instrument.hyst2.value.nxvalue 
TEY_A_6, TEY_B_6, I_A_6,I_B_6 = get_values(file_6) 
TEY_A_7, TEY_B_7,I_A_7,I_B_7 = get_values(file_7) 
TEY_A_8, TEY_B_8,I_A_8,I_B_8 = get_values(file_8) 
TEY_A_9, TEY_B_9,I_A_9,I_B_9 = get_values(file_9)

print(((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)))
print((TEY_A_6)-(TEY_B_6))
print(TEY_A_6,TEY_B_6)
print(I_A_6, I_B_6)
print(TEY_A_6/I_A_6, TEY_B_6/I_B_6)

plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),"s", label="6-8 Norm")
plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),label="6-8 Norm")
plt.plot(B1,  -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),label="9-7 norm")
plt.plot(B1, -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),"d",label="9-7 norm")
# plt.plot(B1, (TEY_A_6)-(TEY_B_6) - ((TEY_A_8)-(TEY_B_8)), label="6-8")
# plt.plot(B1, - ((TEY_A_7)-(TEY_B_7)) + ((TEY_A_9)-(TEY_B_9)),label="9-7")
plt.axhline(y=0)
plt.axvline(x=0)
plt.legend()
# Out:
# ['i06-1-347260.nxs', 'i06-1-347261.nxs', 'i06-1-347262.nxs', 'i06-1-347263.nxs']
# [-1.105102 -1.151425 -1.219157 ... -1.744633 -2.171875 -2.275352]
# [-28200. -29448. -31227. ... -45491. -56574. -59312.]
# [49148. 49254. 48285. ... 34607. 40820. 43156.] [ 77348.  78702.  79512. ...  80098.  97394. 102468.]
# [26272. 26207. 26179. ... 26418. 26396. 26392.] [25992. 25967. 25954. ... 26222. 26193. 26203.]
# [1.870737 1.879422 1.844417 ... 1.309978 1.546446 1.635192] [2.975839 3.030847 3.063574 ... 3.054611 3.718322 3.910545]

# %%
TEY_A_6 = TEY_A_6/I_A_6
TEY_B_6 = TEY_B_6/I_B_6
TEY_A_7 = TEY_A_7/I_A_7
TEY_B_7 = TEY_B_7/I_B_7
TEY_A_8 = TEY_A_8/I_A_8
TEY_B_8 = TEY_B_8/I_B_8
TEY_A_9 = TEY_A_9/I_A_9
TEY_B_9 = TEY_B_9/I_B_9


plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))) #offset in B
plt.axhline(y=0)
plt.axvline(x=0)

# %%
plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8)))))/(0.25*(I_A_6 + I_B_6 + I_A_8 + I_B_8)))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))/(0.25*(I_A_7 + I_B_7 + I_A_9 + I_B_9)))

x = ((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))

print(len(x))
print(x[8])
# Out:
# 15
# -0.27237551753041683

# %%
#3rd hysterisis loop
filepaths = ['i06-1-347264.nxs', 'i06-1-347265.nxs', 'i06-1-347266.nxs', 'i06-1-347267.nxs']
file_6 = filepaths[0] #6
file_7 = filepaths[1] #7
file_8 = filepaths[2] #8
file_9 = filepaths[3] #9
print(filepaths)
def get_values(file):
    
    nexus = nxload(file)
    TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue 
    TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue 
    I_0_A = nexus.entry.instrument.hyst2.detector2_A.nxvalue 
    I_0_B = nexus.entry.instrument.hyst2.detector2_B.nxvalue 
    
    return TEY_A, TEY_B, I_0_A, I_0_B
nexus = nxload(file_6)

B1=nexus.entry.instrument.hyst2.value.nxvalue 
TEY_A_6, TEY_B_6, I_A_6,I_B_6 = get_values(file_6) 
TEY_A_7, TEY_B_7,I_A_7,I_B_7 = get_values(file_7) 
TEY_A_8, TEY_B_8,I_A_8,I_B_8 = get_values(file_8) 
TEY_A_9, TEY_B_9,I_A_9,I_B_9 = get_values(file_9)

print(((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)))
print((TEY_A_6)-(TEY_B_6))
print(TEY_A_6,TEY_B_6)
print(I_A_6, I_B_6)
print(TEY_A_6/I_A_6, TEY_B_6/I_B_6)

plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),"s", label="6-8 Norm")
plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),label="6-8 Norm")
plt.plot(B1,  -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),label="9-7 norm")
plt.plot(B1, -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),"d",label="9-7 norm")
# plt.plot(B1, (TEY_A_6)-(TEY_B_6) - ((TEY_A_8)-(TEY_B_8)), label="6-8")
# plt.plot(B1, - ((TEY_A_7)-(TEY_B_7)) + ((TEY_A_9)-(TEY_B_9)),label="9-7")
plt.axhline(y=0)
plt.axvline(x=0)
plt.legend()
# Out:
# ['i06-1-347264.nxs', 'i06-1-347265.nxs', 'i06-1-347266.nxs', 'i06-1-347267.nxs']
# [-1.190775 -1.23848  -1.3223   ... -1.773589 -2.228106 -2.325109]
# [-30721. -31838. -34029. ... -46412. -58329. -60822.]
# [47902. 48599. 48279. ... 35232. 41529. 43538.] [ 78623.  80437.  82308. ...  81644.  99858. 104360.]
# [26330. 26325. 26296. ... 26553. 26521. 26495.] [26120. 26077. 26061. ... 26333. 26320. 26298.]
# [1.819294 1.846116 1.835983 ... 1.326856 1.565891 1.643253] [3.010069 3.084596 3.158282 ... 3.100444 3.793997 3.968363]

# %%
TEY_A_6 = TEY_A_6/I_A_6
TEY_B_6 = TEY_B_6/I_B_6
TEY_A_7 = TEY_A_7/I_A_7
TEY_B_7 = TEY_B_7/I_B_7
TEY_A_8 = TEY_A_8/I_A_8
TEY_B_8 = TEY_B_8/I_B_8
TEY_A_9 = TEY_A_9/I_A_9
TEY_B_9 = TEY_B_9/I_B_9



plotting = (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))
plotting_2 = (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8)))))

print(plotting[8])
print(B1[8])

plt.plot(B1, plotting)
plt.plot(B1, plotting_2) #offset in B
plt.axhline(y=0)
plt.axvline(x=0)
# Out:
# 0.0075267143314883865
# 0.005

# %%
#plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8)))))/(0.25*(I_A_6 + I_B_6 + I_A_8 + I_B_8)))
#plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))/(0.25*(I_A_7 + I_B_7 + I_A_9 + I_B_9)))

up_loop = (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8)))))/(0.25*(I_A_6 + I_B_6 + I_A_8 + I_B_8))
down_loop = (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))/(0.25*(I_A_7 + I_B_7 + I_A_9 + I_B_9))
plt.plot(B1[10:17],up_loop[10:17])
plt.plot(B1[10:17],down_loop[10:17])
x = ((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))
plt.axhline(y=0)
plt.axvline(x=0)
print(len(x))
print(x[8])
# Out:
# 15
# -0.10660636197623716

# %%
# 3rd hysterisis loop in grazing
#3rd hysterisis loop
filepaths = ['i06-1-347268.nxs', 'i06-1-347269.nxs', 'i06-1-347270.nxs', 'i06-1-347271.nxs']
file_6 = filepaths[0] #6
file_7 = filepaths[1] #7
file_8 = filepaths[2] #8
file_9 = filepaths[3] #9
print(filepaths)
def get_values(file):
    
    nexus = nxload(file)
    TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue 
    TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue 
    I_0_A = nexus.entry.instrument.hyst2.detector2_A.nxvalue 
    I_0_B = nexus.entry.instrument.hyst2.detector2_B.nxvalue 
    
    return TEY_A, TEY_B, I_0_A, I_0_B
nexus = nxload(file_6)

B1=nexus.entry.instrument.hyst2.value.nxvalue 
TEY_A_6, TEY_B_6, I_A_6,I_B_6 = get_values(file_6) 
TEY_A_7, TEY_B_7,I_A_7,I_B_7 = get_values(file_7) 
TEY_A_8, TEY_B_8,I_A_8,I_B_8 = get_values(file_8) 
TEY_A_9, TEY_B_9,I_A_9,I_B_9 = get_values(file_9)

print(((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)))
print((TEY_A_6)-(TEY_B_6))
print(TEY_A_6,TEY_B_6)
print(I_A_6, I_B_6)
print(TEY_A_6/I_A_6, TEY_B_6/I_B_6)

plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),"s", label="6-8 Norm")
plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),label="6-8 Norm")
plt.plot(B1,  -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),label="9-7i06-1-347268.nxs norm")
plt.plot(B1, -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),"d",label="9-7 norm")
# plt.plot(B1, (TEY_A_6)-(TEY_B_6) - ((TEY_A_8)-(TEY_B_8)), label="6-8")
# plt.plot(B1, - ((TEY_A_7)-(TEY_B_7)) + ((TEY_A_9)-(TEY_B_9)),label="9-7")
plt.axhline(y=0)
plt.axvline(x=0)
plt.legend()
# Out:
# ['i06-1-347268.nxs', 'i06-1-347269.nxs', 'i06-1-347270.nxs', 'i06-1-347271.nxs']
# [-1.14718  -1.088578 -0.927829 ... -0.590829 -0.552548 -0.531985]
# [-29851. -28346. -24108. ... -15175. -14142. -13705.]
# [40440. 38901. 34931. ... 42087. 43502. 43652.] [70291. 67247. 59039. ... 57262. 57644. 57357.]
# [26545. 26530. 26518. ... 26456. 26453. 26427.] [26320. 26321. 26297. ... 26247. 26237. 26265.]
# [1.523451 1.466302 1.317256 ... 1.59083  1.644502 1.651796] [2.670631 2.55488  2.245085 ... 2.181659 2.19705  2.183781]

# %%
TEY_A_6 = TEY_A_6/I_A_6
TEY_B_6 = TEY_B_6/I_B_6
TEY_A_7 = TEY_A_7/I_A_7
TEY_B_7 = TEY_B_7/I_B_7
TEY_A_8 = TEY_A_8/I_A_8
TEY_B_8 = TEY_B_8/I_B_8
TEY_A_9 = TEY_A_9/I_A_9
TEY_B_9 = TEY_B_9/I_B_9


plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - Ti06-1-347268.nxsEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))) #offset in B
plt.axhline(y=0)
plt.axvline(x=0)

# %%
# 3rd hysterisis loop in grazing
#3rd hysterisis loop
filepaths = ['i06-1-347273.nxs', 'i06-1-347274.nxs', 'i06-1-347275.nxs', 'i06-1-347276.nxs']
file_6 = filepaths[0] #6
file_7 = filepaths[1] #7
file_8 = filepaths[2] #8
file_9 = filepaths[3] #9
print(filepaths)
def get_values(file):
    
    nexus = nxload(file)
    TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue 
    TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue 
    I_0_A = nexus.entry.instrument.hyst2.detector2_A.nxvalue 
    I_0_B = nexus.entry.instrument.hyst2.detector2_B.nxvalue 
    
    return TEY_A, TEY_B, I_0_A, I_0_B
nexus = nxload(file_6)

B1=nexus.entry.instrument.hyst2.value.nxvalue 
TEY_A_6, TEY_B_6, I_A_6,I_B_6 = get_values(file_6) 
TEY_A_7, TEY_B_7,I_A_7,I_B_7 = get_values(file_7) 
TEY_A_8, TEY_B_8,I_A_8,I_B_8 = get_values(file_8) 
TEY_A_9, TEY_B_9,I_A_9,I_B_9 = get_values(file_9)

print(((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)))
print((TEY_A_6)-(TEY_B_6))
print(TEY_A_6,TEY_B_6)
print(I_A_6, I_B_6)
print(TEY_A_6/I_A_6, TEY_B_6/I_B_6)

plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),"s", label="6-8 Norm")
plt.plot(B1, ((TEY_A_6/I_A_6)-(TEY_B_6/I_B_6)) - ((TEY_A_8/I_A_8)-(TEY_B_8/I_B_8)),label="6-8 Norm")
plt.plot(B1,  -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),label="9-7i06-1-347268.nxs norm")
plt.plot(B1, -((TEY_A_7/I_A_7)-(TEY_B_7/I_B_7)) + ((TEY_A_9/I_A_9)-(TEY_B_9/I_B_9)),"d",label="9-7 norm")
# plt.plot(B1, (TEY_A_6)-(TEY_B_6) - ((TEY_A_8)-(TEY_B_8)), label="6-8")
# plt.plot(B1, - ((TEY_A_7)-(TEY_B_7)) + ((TEY_A_9)-(TEY_B_9)),label="9-7")
plt.axhline(y=0)
plt.axvline(x=0)
plt.legend()
# Out:
# ['i06-1-347273.nxs', 'i06-1-347274.nxs', 'i06-1-347275.nxs', 'i06-1-347276.nxs']
# [-2.066425 -1.993789 -1.693599 ... -1.235628 -1.168253 -1.138049]
# [-54210. -52305. -44475. ... -32071. -30321. -29508.]
# [43437. 41807. 37277. ... 45334. 46638. 47078.] [97647. 94112. 81752. ... 77405. 76959. 76586.]
# [26686. 26613. 26606. ... 26447. 26446. 26482.] [26433. 26401. 26417. ... 26241. 26250. 26266.]
# [1.627707 1.570924 1.401075 ... 1.714145 1.763518 1.777736] [3.694132 3.564713 3.094674 ... 2.949773 2.931771 2.915785]

# %%
TEY_A_6 = TEY_A_6/I_A_6
TEY_B_6 = TEY_B_6/I_B_6
TEY_A_7 = TEY_A_7/I_A_7
TEY_B_7 = TEY_B_7/I_B_7
TEY_A_8 = TEY_A_8/I_A_8
TEY_B_8 = TEY_B_8/I_B_8
TEY_A_9 = TEY_A_9/I_A_9
TEY_B_9 = TEY_B_9/I_B_9


plt.plot(B1, (((TEY_A_6 - TEY_B_6) - (TEY_A_8 - TEY_B_8))/(0.5 * (((TEY_A_6 - TEY_B_6) + (TEY_A_8 - TEY_B_8))))))
plt.plot(B1, (((TEY_A_9 - TEY_B_9) - (TEY_A_7 - TEY_B_7))/(0.5 * (((TEY_A_9 - TEY_B_9) + (TEY_A_7 - TEY_B_7)))))) #offset in B
plt.axhline(y=0)
plt.axvline(x=0)

# %% [markdown]
# ## END OF DAY 1 -> continued in Hysteresis_30
