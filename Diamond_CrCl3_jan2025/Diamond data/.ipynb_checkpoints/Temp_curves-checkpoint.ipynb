# %%
import matplotlib.pyplot as plt
import numpy as np




saturation_BP = [1.239343,1.1280,1.1478,1.0631,1.12768,1.06549,1.145,0.8519,1.0798,0.8947,]
rem_BP = [0.57908,0.18008,0.153397, 0.0882,0.12549899,0.07769,0.14678,0.02605,0.07149,0.0361657,]
temp_BP = [2,8,10,11.8,11,12.2,12.4,12.5,12.6,12.6,]

Tc = 13
temp = np.arange(0,13,0.01)
temp_tc = 0.15*(1-temp/Tc)**0.225

plt.plot(temp, temp_tc)

plt.scatter(temp_BP, rem_BP)
