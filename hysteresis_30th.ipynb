# %%
# Out:
# Autosaving every 60 seconds

# %%
files = ['i06-1-347273.nxs', 'i06-1-347274.nxs', 'i06-1-347275.nxs', 'i06-1-347276.nxs']
Hysteresis(files)

# %%
files = ['i06-1-347277.nxs', 'i06-1-347278.nxs', 'i06-1-347279.nxs', 'i06-1-347280.nxs']
Hysteresis(files, offset=[-0.5,0.5])

# %%
files = ['i06-1-347283.nxs', 'i06-1-347285.nxs', 'i06-1-347286.nxs', 'i06-1-347284.nxs']
Hysteresis(files, offset=[-0.5,0.5])

### Hysteresis on the L3 edge rather than L2. Random 0 points but reasonable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 2
#       1 files = ['i06-1-347283.nxs', 'i06-1-347285.nxs', 'i06-1-347286.nxs', 'i06-1-347284.nxs']
# ----> 2 Hysteresis(files, offset=[-0.5,0.5])
#       4 ### Hysteresis on the L3 edge rather than L2. Random 0 points but reasonable
#
# Cell In[62], line 25, in Hysteresis(files, offset)
#      22 values = {}
#      24 for file in files:
# ---> 25     data = get_values("FILES/HOPG1/Hysteresis/" + file)
#      26     for i, datum in enumerate(data):
#      27         values[f"{file} {i}"] = datum # 0 = TeyA, 1 = TEYB, 2 = I0A, 3 = I0B
#
# Cell In[62], line 9, in get_values(file)
#       6 def get_values(file):
#       8     nexus = nxload(file)
# ----> 9     TEY_A=nexus.entry.instrument.hyst2.detector1_A.nxvalue
#      10     TEY_B=nexus.entry.instrument.hyst2.detector1_B.nxvalue
# ...

# %%
sat = np.array([0.91,0.954,0.667,1.141,0.998,0.575,1.084,0.598,0.671])
rem = np.array([0.25,0.253,0.102,0.081,0.1,0.032,0.054,0.035,0.02])
temp = np.array([2,2,10,12.5,12,13.5,13,14,20])
print(len(sat),len(rem), len(temp))
r_s = rem/sat

plt.scatter(temp, rem)
# Out:
# 9 9 9

# %%
sat = np.array([1.110,0.868,0.900,0.987,0.951,1.2579])
rem = np.array([0.098,0.0549,0.048,0.0586,0.0797,0.5798])
temp = np.array([12,13,14,15,17,2])
print(len(sat),len(rem), len(temp))
r_s = rem/sat

plt.scatter(temp, rem)
# Out:
# 6 6 6
